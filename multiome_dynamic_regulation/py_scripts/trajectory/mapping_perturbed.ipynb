# %%
import numpy as np
import pandas as pd
import anndata as ad
import matplotlib.pyplot as plt

import os
import sys
import logging

# %%
stream_object = '/ocean/projects/cis240075p/asachan/datasets/B_Cell/multiome_1st_donor_UPMC_aggr/other_files/objects/mlle_traj_male_donor.pkl'
output_folder = '/ocean/projects/cis240075p/asachan/datasets/B_Cell/multiome_1st_donor_UPMC_aggr/other_files/objects'
adata_infile = os.path.join(output_folder, 'stream_input_perturb_seq.h5ad')

# %%
from os.path import basename
import stream as st
#read the stream result file pkl or h5ad
adata_perturb = st.read(file_name=adata_infile, workdir=output_folder)
trajectory_object = st.read(file_name=stream_object, workdir=output_folder)
# Out:
# /ocean/projects/cis240075p/asachan/.conda/envs/env_stream/lib/python3.7/site-packages/rpy2/robjects/pandas2ri.py:17: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import Index as PandasIndex
# Saving results in: /ocean/projects/cis240075p/asachan/datasets/B_Cell/multiome_1st_donor_UPMC_aggr/other_files/objects
# Working directory is already specified as '/tmp/tmpxe4adudq'
# To change working directory, please run set_workdir(adata,workdir=new_directory)

# %%
trajectory_object
# Out:
# AnnData object with n_obs × n_vars = 28494 × 4142
# ...

# %%
# Extract gene names (usually in .var_names)
gene_names = trajectory_object.var_names
# Convert to DataFrame
gene_names_df = pd.DataFrame(gene_names, columns=["gene"])
# Save to CSV
gene_names_df.to_csv(os.path.join(output_folder, "gene_names_mlle.csv"), index=False)

# %%
adata_perturb
# Out:
# AnnData object with n_obs × n_vars = 4689 × 3012
# ...

# %%
adata_combined = st.map_new_data(trajectory_object,adata_perturb)
# Out:
# Top variable genes are being used for mapping ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_13435/646632711.py in <module>
# ----> 1 adata_combined = st.map_new_data(trajectory_object,adata_perturb)
#
# /ocean/projects/cis240075p/asachan/.conda/envs/env_stream/lib/python3.7/site-packages/stream/core.py in map_new_data(adata_ref, adata_new, use_radius)
#    4047         for x in adata_ref.uns['var_genes']:
#    4048             if(x not in adata_new.var_names):
# -> 4049                 raise ValueError("variable gene '%s' does not exist in `adata_new.var_names`"  % (x))
#    4050         adata_new.uns['var_genes'] = adata_ref.uns['var_genes'].copy()
#    4051         adata_new.obsm['var_genes'] = adata_new[:,adata_new.uns['var_genes']].X.copy()
#
# ValueError: variable gene 'CAMTA1-DT' does not exist in `adata_new.var_names`
